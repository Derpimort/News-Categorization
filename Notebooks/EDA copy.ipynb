# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("max_columns",100)
pd.set_option("max_colwidth",500)
sns.set(context="notebook", style="whitegrid", palette="deep", font_scale=1)

DATA_DIR="data/"
DATA_DIR+="cleaned/"

# %%
df_train=pd.read_pickle(DATA_DIR+"train_cleaned.pkl")
df_train.head(2)
# Out:
#                                                                                                                     title  \
# 0  ପ୍ରବଳ ଶୀତରେ ଥରୁଛି ସାରା ଓଡ଼ିଶା । ୧୩ଟି ଜିଲ୍ଲା ପାଇଁ ୟେଲୋ ୱାର୍ଣ୍ଣିଂ ଜାରି କଲା ପାଣିପାଗ ବିଭାଗ : କୋଇଡା ଓ ଦାରିଙ୍ଗବାଡିରେ ତୁଷାରପାତ
# 1                                                             'संघर्षशील और जुझारू संस्कृतिकर्मी थे संदीपन विमलकांत नागर'
#
#                                                                                                                                                                link  \
# 0                                     https://www.newspointapp.com/odia-news/publisher-kanaknews-odia/top-news/articleshow/145048207eb97f903061bbd718a8a970ef3652c3
# 1  https://navbharattimes.indiatimes.com/metro/lucknow/other-news/sandeepan-vimalkant-nagar-was-a-struggling-and-combative-cultural-worker/articleshow/73022935.cms
#
#                                                                                                                                                                                                    description  \
# 0  କନକ ବ୍ୟୁରୋ : ଜାଡରେ ଥରୁଛି ସାରା ଓଡିଶା । ସ୍ୱାଭାବିକ ଠାରୁ ୬ଡିଗ୍ରୀ ଖସିଆସିଛି ପାରଦ । ଆହୁରି ଦୁଇ ଦିନ ଅତି ପ୍ରବଳ ଥଣ୍ଡା ଅନୁଭୂତ ହେବ । ଏଥିପାଇଁ ଅଧି ଓଡିଶାରେ ୟେଲୋ ୱାର୍ଣ୍ଣିଂ ଜାରି ହୋଇଛି । ୧୩ଟି ଜିଲ୍ଲାରେ ଜିଲ୍ଲା ପ୍ରଶାସନକୁ ସ...
# 1                                                         \Bसंदीपन ने कलाकारों को दिशा देने के साथ नाट्य चेतना जाग्रत की। यह बात वरिष्ठ रंगकर्मी और अभिनेता राकेश पाण्डेय ने मथुरा के रंगकर्मी और ब्रजभाषी ...
#
#                                                                                                                                                                                               long_description  \
# 0  କନକ ବ୍ୟୁରୋ : ଜାଡରେ ଥରୁଛି ସାରା ଓଡିଶା । ସ୍ୱାଭାବିକ ଠାରୁ ୬ଡିଗ୍ରୀ ଖସିଆସିଛି ପାରଦ । ଆହୁରି ଦୁଇ ଦିନ ଅତି ପ୍ରବଳ ଥଣ୍ଡା ଅନୁଭୂତ ହେବ । ଏଥିପାଇଁ ଅଧି ଓଡିଶାରେ ୟେଲୋ ୱାର୍ଣ୍ଣିଂ ଜାରି ହୋଇଛି । ୧୩ଟି ଜିଲ୍ଲାରେ ଜିଲ୍ଲା ପ୍ରଶାସନକୁ ସ...
# 1                         B Sandipan awakened the play with consciousness giving direction to the artists. This was said by senior painter and actor Rakesh Pandey, Mathura color worker and Braj-speaking ...
#
#      id
# 0  2674
# 1  3874

# %%
df_nulls=df_train.isna().apply(pd.Series.value_counts).T
df_nulls.columns=['Not-Null', 'Null']
ax=df_nulls.plot(kind="barh", stacked=True, figsize=(12,6), alpha=0.5, color=sns.color_palette()[2:4])
for p in ax.patches:
    width=p.get_width()
    if width!=0:
        ax.annotate("%d"%width, 
                (p.get_x(), p.get_y()), 
                xytext=(5, 10),
                textcoords='offset points')
plt.title("NAs in columns")
# plt.savefig("plots/nulls.png")
plt.show()

# %%
df_train['id'].unique().shape
# Out:
# (1411103,)

# %%
from preprocess import get_sentences
from urllib.parse import urlparse
from pandarallel import pandarallel
import gc

# pandarallel.initialize(nb_workers=3, progress_bar=True)
pandarallel.initialize()

def parse_urls(row):
    return urlparse(row).path

urls=df_train['link'].dropna().parallel_apply(parse_urls)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
del df_train
gc.collect()
# Out:
# 21

# %%
df_langs=pd.read_csv(DATA_DIR+"langs.csv")
df_langs=df_langs.set_index('id')
df_langs.head()
# Out:
#      title_lang description_lang long_description_lang
# id
# 2674         ne               ne                    ne
# 3874         hi               hi                    en
# 425          mr          unknown               unknown
# 5177         en               en                    en
# 3260         ta               ta                    en

# %% [markdown]
# ### Top 20 languages for title, description and long_description
# > As evident, most available long_descriptions are in english

# %%
plt.figure(figsize=(24,10))
sns.countplot(x="value", hue="variable", data=pd.melt(df_langs), order=df_langs['title_lang'].value_counts().iloc[:20].index)
# plt.savefig("plots/langs.png")
plt.show()

# %% [markdown]
# ### Number of titles in each language

# %%
plt.figure(figsize=(16,6))
plot=sns.countplot(x='title_lang', data=df_langs, order=df_langs['title_lang'].value_counts().index)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')
# plt.savefig("plots/titlelangs.png")
plt.show()

# %% [markdown]
# ### How many articles with no long_description have either of title or decription in english

# %%
ax=sns.countplot(np.any(df_langs[df_langs['long_description_lang']=='unknown']=='en', axis=1))
for p in ax.patches:
    ax.annotate('%d'%(p.get_height()), (p.get_x()+p.get_width()/3, p.get_height()+1000))
# plt.savefig("plots/url_articlecount.png")

# %% [markdown]
# ### Use title/description for unknown 60996 and just clean the url for the rest.

# %% [markdown]
# # Keyword extraction results

# %%
# sub=[]
# sub+=[pd.read_pickle(DATA_DIR+"submission_352775.pkl")]
# sub+=[pd.read_pickle(DATA_DIR+"submission_705550.pkl")]
# sub+=[pd.read_pickle(DATA_DIR+"submission_1058325.pkl")]
# sub+=[pd.read_pickle(DATA_DIR+"submission_1411104.pkl")]

# %%
# df_sub=pd.concat(sub)
# df_sub.to_csv(DATA_DIR+"submission_full.csv")
# df_sub.to_pickle(DATA_DIR+"submission_full.pkl")
df_sub = pd.read_csv(DATA_DIR+"submission_full.csv")

# %%
sizes=[]
for row in df_sub.values:
    sizes.append(row[0])

# %%
sizes=pd.Series(sizes)
sizes.describe()
# Out:
# count    1.411103e+06
# mean     7.062998e+05
# std      4.078196e+05
# min      0.000000e+00
# 25%      3.531035e+05
# 50%      7.062790e+05
# 75%      1.059450e+06
# max      1.412643e+06
# dtype: float64

# %%
# plt.figure(figsize=(24,10))
# sns.countplot(sizes)
# # plt.savefig("plots/keywords.png")
# plt.show()
sizes
# Out:
# 0            2674
# 1            3874
# 2             425
# 3            5177
# 4            3260
#             ...
# 1411098    164269
# 1411099    164483
# 1411100    165505
# 1411101    162919
# 1411102    168359
# Length: 1411103, dtype: int64
